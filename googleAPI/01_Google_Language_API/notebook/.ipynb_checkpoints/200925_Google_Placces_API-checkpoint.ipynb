# %% [markdown]
# # Google Places API

# %% [markdown]
# https://qiita.com/mgmgmogumi/items/f160d28a0643f683afeb
# https://www.for-engineer.life/entry/python-google-api/

# %%
import googlemaps # conda install -c conda-forge googlemaps
import pprint # list型やdict型を見やすくprintするライブラリ

# %%
key = 'AIzaSyDdD2_MXkqs0np86wZIe9kcWobqETRRaAg' # 作成したAPIキーを入れる

client = googlemaps.Client(key) #インスタンス生成

# %%
loc = {'lat': 35.6360334, 'lng': 140.1492332} # 総武線都賀駅の緯度、経度を設定。

# 半径100m以内のカフェ情報を取得
place_results = client.places_nearby(location=loc, radius=100, keyword='カフェ',language='ja')
pprint.pprint(place_results)
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 35.6359213, 'lng': 140.1486902},
#                            'viewport': {'northeast': {'lat': 35.63725712989273,
#                                                       'lng': 140.1500557298928},
#                                         'southwest': {'lat': 35.63455747010729,
#                                                       'lng': 140.1473560701073}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/cafe-71.png',
#               'name': 'ＨｏＢｏｃａｆｅ',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1280,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100321822413758566412">かんと君</a>'],
# ...

# %%
# 検索語の入力
keyword = input("検索したい場所を入力してください")
radium = input("検索範囲を入力してください（メートル）")
place_results = client.places_nearby(location=loc, radius=100, keyword=keyword,language='ja')
pprint.pprint(place_results)
# Out:
# 検索したい場所を入力してください牛丼屋
# 検索範囲を入力してください（メートル）30
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 35.6356017, 'lng': 140.1497938},
#                            'viewport': {'northeast': {'lat': 35.63702587989272,
#                                                       'lng': 140.1510390298927},
#                                         'southwest': {'lat': 35.63432622010728,
#                                                       'lng': 140.1483393701073}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#               'name': 'なか卯 都賀駅前店',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2976,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102547986753942596669">janne '
# ...

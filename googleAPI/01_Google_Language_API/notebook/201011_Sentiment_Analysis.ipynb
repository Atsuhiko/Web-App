# %% [markdown]
# # Sentiment Analysis by GCP API

# %% [markdown]
# https://developers.wonderpla.net/entry/2017/11/28/110000

# %%
import requests 

# API キーを作成
# https://console.cloud.google.com/apis/credentials?hl=ja&project=striking-yen-262512
#APIキーを入力
key = "AIzaSyDdD2_MXkqs0np86wZIe9kcWobqETRRaAg"

#感情分析したいテキスト
# text = "こんにちは、今日もいい天気ですね。明日も晴れるといいなあ。でも最近晴れてるのに寒いですよね。"

# text = '''
# 今日はガチ勢の友人と一緒にボルダリングをした。休日だけあってとても混んでいたが、その分他の人の登り方を参考にしたり、アドバイスを受けることができた。  
# おかげで、今まではどう登ればいいのかわからなかった壁の登り方がわかり、実際に登ることができたのでとても気分が良い。  
# また、上手い人の登り方を見ていると「自分の課題」も浮き彫りになるので、とても参考になる。  
# 平日は自分が登ることがメインで、休日は人の登り方を参考にじっくり登る、といった使い分けができそうだ。  
# '''

# %%
text = open("./text/A_Cosme.txt", mode="r", encoding="shift-jis").read()

# %%
#APIのURL
url = "https://language.googleapis.com/v1/documents:analyzeSentiment?key=" + key

#基本情報の設定 JAをENにすれば英語のテキストを解析可能
header = {'Content-Type': 'application/json'}
body = {
    "document": {
        "type": "PLAIN_TEXT",
        "language": "JA",
        "content": text
    },
    "encodingType": "UTF8"
}
 
#json形式で結果を受け取る。
response = requests.post(url, headers=header, json=body).json()

# %%
#分析の結果をコンソール画面で見やすく表示
print("総合magnitude:",response["documentSentiment"]["magnitude"])
print("総合score:",response["documentSentiment"]["score"])
for i in response["sentences"]:
    print(i["text"]["content"],"magnitude:",i["sentiment"]["magnitude"],", score:",i["sentiment"]["score"])
# Out:
# 総合magnitude: 267.7
# 総合score: 0.2
# 毛のハネを抑えてくれる効果を期待しましたが… magnitude: 0.7 , score: -0.7
# 普通に朝起きたらハネます。 magnitude: 0.1 , score: 0.1
# 地肌にも合わなかったのか、吹き出物が続いたのでリピはないです。 magnitude: 0.8 , score: -0.8
# いち髪（白黒）から買って見ました。 magnitude: 0 , score: 0
# しっとり感は、エッセンシャルの方が上かなぁ？ magnitude: 0 , score: 0
# いち髪の白黒は、しっとりよりも、フワッさらっと仕上がる感じだなぁと、使ってみて改めて思いました。 magnitude: 0.4 , score: 0.4
# ブローの時、手ぐしで動かしやすくなった気がします。 magnitude: 0.9 , score: 0.9
# ベリーショートなので、毛流れが重要ですけど、何となく楽になったかな？ magnitude: 0.5 , score: 0.5
# でも、寝癖が付きにくいとかはないです！ magnitude: 0.6 , score: 0.6
# 本当に何となーく、ブローが楽になった感じですねf(^ー^;
# 可もなく不可もなくと思いきや、いろいろと試す中で、朝起きて一番髪が落ち着いてるし、手ぐしで戻るところが楽で... magnitude: 0.9 , score: 0.9
# 他のシャンプーは朝になると爆発してることが多いのでセットに時間がかかりますがエッセンシャルは朝の時短になっていいです。 magnitude: 0.8 , score: 0.8
# 洗い心地とか、しっとり感とか髪質は変わりませんが笑 時短になるのでまたリピします！ magnitude: 0.9 , score: 0.9
# ここでの口コミがあまり良くなくてビックリしました！ magnitude: 0.3 , score: -0.3
# 私の髪にはとっても合うので、サラサラになります。 magnitude: 0.9 , score: 0.9
# ...

# %%
response
# Out:
# {'documentSentiment': {'magnitude': 267.7, 'score': 0.2},
#  'language': 'ja',
#  'sentences': [{'text': {'content': '毛のハネを抑えてくれる効果を期待しましたが…',
#     'beginOffset': 0},
#    'sentiment': {'magnitude': 0.7, 'score': -0.7}},
#   {'text': {'content': '普通に朝起きたらハネます。', 'beginOffset': 66},
#    'sentiment': {'magnitude': 0.1, 'score': 0.1}},
#   {'text': {'content': '地肌にも合わなかったのか、吹き出物が続いたのでリピはないです。', 'beginOffset': 105},
#    'sentiment': {'magnitude': 0.8, 'score': -0.8}},
#   {'text': {'content': 'いち髪（白黒）から買って見ました。', 'beginOffset': 199},
#    'sentiment': {'magnitude': 0, 'score': 0}},
#   {'text': {'content': 'しっとり感は、エッセンシャルの方が上かなぁ？', 'beginOffset': 250},
#    'sentiment': {'magnitude': 0, 'score': 0}},
#   {'text': {'content': 'いち髪の白黒は、しっとりよりも、フワッさらっと仕上がる感じだなぁと、使ってみて改めて思いました。',
#     'beginOffset': 316},
#    'sentiment': {'magnitude': 0.4, 'score': 0.4}},
#   {'text': {'content': 'ブローの時、手ぐしで動かしやすくなった気がします。', 'beginOffset': 460},
#    'sentiment': {'magnitude': 0.9, 'score': 0.9}},
# ...

# %% [markdown]
# ## 関数化

# %%
def sentiment_analysis(text):
    #APIのURL
    url = "https://language.googleapis.com/v1/documents:analyzeSentiment?key=" + key
    
    #基本情報の設定 JAをENにすれば英語のテキストを解析可能
    header = {'Content-Type': 'application/json'}
    body = {
        "document": {
            "type": "PLAIN_TEXT",
            "language": "JA",
            "content": text
        },
        "encodingType": "UTF8"
    }
 
    #json形式で結果を受け取る。
    response = requests.post(url, headers=header, json=body).json()
    
    return response

# %%
def print_analysis(response):
    #分析の結果をコンソール画面で見やすく表示
    print("総合magnitude:",response["documentSentiment"]["magnitude"])
    print("総合score:",response["documentSentiment"]["score"])
    for i in response["sentences"]:
        print(i["text"]["content"],"magnitude:",i["sentiment"]["magnitude"],", score:",i["sentiment"]["score"])

# %%
def sentiment_analysis2(text):
    response = sentiment_analysis(text)
    print_analysis(response)

# %%
text = open("./text/A_Cosme.txt", mode="r", encoding="shift-jis").read()

# %%
sentiment_analysis2(text)
# Out:
# 総合magnitude: 267.7
# 総合score: 0.2
# 毛のハネを抑えてくれる効果を期待しましたが… magnitude: 0.7 , score: -0.7
# 普通に朝起きたらハネます。 magnitude: 0.1 , score: 0.1
# 地肌にも合わなかったのか、吹き出物が続いたのでリピはないです。 magnitude: 0.8 , score: -0.8
# いち髪（白黒）から買って見ました。 magnitude: 0 , score: 0
# しっとり感は、エッセンシャルの方が上かなぁ？ magnitude: 0 , score: 0
# いち髪の白黒は、しっとりよりも、フワッさらっと仕上がる感じだなぁと、使ってみて改めて思いました。 magnitude: 0.4 , score: 0.4
# ブローの時、手ぐしで動かしやすくなった気がします。 magnitude: 0.9 , score: 0.9
# ベリーショートなので、毛流れが重要ですけど、何となく楽になったかな？ magnitude: 0.5 , score: 0.5
# でも、寝癖が付きにくいとかはないです！ magnitude: 0.6 , score: 0.6
# 本当に何となーく、ブローが楽になった感じですねf(^ー^;
# 可もなく不可もなくと思いきや、いろいろと試す中で、朝起きて一番髪が落ち着いてるし、手ぐしで戻るところが楽で... magnitude: 0.9 , score: 0.9
# 他のシャンプーは朝になると爆発してることが多いのでセットに時間がかかりますがエッセンシャルは朝の時短になっていいです。 magnitude: 0.8 , score: 0.8
# 洗い心地とか、しっとり感とか髪質は変わりませんが笑 時短になるのでまたリピします！ magnitude: 0.9 , score: 0.9
# ここでの口コミがあまり良くなくてビックリしました！ magnitude: 0.3 , score: -0.3
# 私の髪にはとっても合うので、サラサラになります。 magnitude: 0.9 , score: 0.9
# ...

# %% [markdown]
# ## テキストデータスクレイピング

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
html=requests.get("https://barconcertvienne.com/etc/27209/").text
soup=BeautifulSoup(html,"html.parser")

# scriptやstyleを含む要素を削除する
for script in soup(["script", "style"]):
    script.decompose()
# テキストのみを取得=タグは全部取る
text=soup.get_text()
# 改行を削除
text = text.replace('\n', '')

# %%
sentiment_analysis2(text)
# Out:
# 総合magnitude: 30.4
# 総合score: 0.2
# 特別定額給付金を地域に還元！ magnitude: 0 , score: 0
# 千葉駅周辺で頂く、ちょっと贅沢な極上グルメ　厳選10軒、絶品料理の数々をご紹介！！ magnitude: 0.9 , score: 0.9
# | 孤高の千葉グルメ 運営者情報 お問い合わせ サイトマップ twitter RSS 孤高の千葉グルメ 千葉市を中心とした、孤独なようで孤独でもない、ちょっと孤高な食べ歩き。 magnitude: 0.1 , score: 0.1
# だいたい当たりますが、時々派手にスベります。 magnitude: 0.2 , score: 0.2
# Menuコンテンツへ移動TOPへお勧め千葉グルメ新店情報最新グルメニュース子供連れOKのお店お問い合わせ深夜版ホーム千葉グルメ 役立つまとめ情報特別定額給付金を地域に還元！ magnitude: 0.1 , score: 0.1
# 千葉駅周辺で頂く、ちょっと贅沢な極上グルメ　厳選10軒、絶品料理の数々をご紹介！！ magnitude: 0.9 , score: 0.9
# 														特別定額給付金を地域に還元！ magnitude: 0 , score: 0
# 千葉駅周辺で頂く、ちょっと贅沢な極上グルメ　厳選10軒、絶品料理の数々をご紹介！！ magnitude: 0.9 , score: 0.9
# スポンサードリンクTweet Pocket新型コロナウイルスの影響で、景気、経済が落ち込む中国民に経済活動を推し進めるべく、一律10万円が給付されるものとなった、特別定額給付金 ※ 先週、我が家にもやっと届きました この使い道は、様々でしょうが私としては、地域に還元することで地元のお店らに活気づいて貰いたい 特に、この新型コロナの影響を受けた飲食店にこそ、しっかり還元したいそう考えておりまして で、せっかく頂く10万円の給付金これを使って外食産業に貢献しようと思ってはみたものの給付金の有無に関わらず、普段から地元で食べ歩いている身としては 「せっかくの10万円なら、普段は食べられない贅沢グルメを頂きたい！」 magnitude: 0 , score: 0
# ...
